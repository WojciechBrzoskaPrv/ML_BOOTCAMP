# %% [markdown]
# <a href="https://colab.research.google.com/github/WojciechBrzoskaPrv/ML_BOOTCAMP/blob/main/pyAlgo_BinarySearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as ra
from sys import *
def binarySearch(anyList,searchedValue):
  i_start=0
  i_end=len(anyList)
  mid=int((i_end-i_start)/2)
  print('current list is {} Mid value ={} Mid ={} Start ={} End ={}'.format(anyList,anyList[mid],mid,i_start,i_end-1))
  if len(anyList)<=2 and searchedValue not in anyList:
      return -maxsize-1
  if searchedValue>anyList[mid]:
    i_start=mid+1
    lb=len(anyList)
    anyList=anyList[i_start:i_end+1]
    offset=(lb-len(anyList))
    return binarySearch(anyList,searchedValue)+offset
  if searchedValue<anyList[mid]:
    i_end=mid-1
    
    anyList=anyList[i_start:i_end+1]
    return binarySearch(anyList,searchedValue)
  if searchedValue==anyList[mid]:
    return mid

def myFactorial(num):
  if num>0:
    return num*myFactorial(num-1)
  else: 
    return 1  

print(myFactorial(7))


#myList=[1, 3, 5, 6, 8, 10, 12, 18, 21, 22, 24, 25, 26, 27, 28, 32, 33, 34, 36, 37, 39, 41, 42, 43, 45, 46, 48, 49, 50, 51, 52, 53, 58, 59, 60, 61, 62, 64, 65, 66, 67, 68, 69, 70, 72, 73, 76, 79, 81, 83, 84, 86, 88, 89, 90, 91, 93, 94, 95, 96, 98, 99, 100, 101, 103, 107]
myList=[]
for i in range(100000):
  myList.append(ra.randint(1,100000))
mySet=set(myList)
myList=list(mySet)
myList=sorted(myList)

print(myList)
searchedValue=15
idx=binarySearch(myList,searchedValue)

if idx>=0:
  print('Found at idx {} value {}:'.format(idx,myList[idx]))
else:
  print('Not found')
# Out:
# 5040
# ...
